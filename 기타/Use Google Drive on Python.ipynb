# %% [markdown]
# 참고 사이트 주소: \
# https://jsikim1.tistory.com/205 \
# https://pbj0812.tistory.com/184

# %%
from oauth2client.service_account import ServiceAccountCredentials
import gspread

scope = ["https://spreadsheets.google.com/feeds",
         "https://www.googleapis.com/auth/drive",]

# JSON Key File Path
json_key_path = "C:/Users/limjw/OneDrive/바탕 화면/j1lim/HRU/google_api/massive-oasis-357803-325743f36cb3.json"

credential = ServiceAccountCredentials.from_json_keyfile_name(json_key_path, scope)
gc = gspread.authorize(credential)

# URL로 열기
spreadsheet_url = "https://docs.google.com/spreadsheets/d/1QjtdghWeypM-vGUkQADaDkJUEljV44IPViFeR43zvvM/edit#gid=1134538840"
doc = gc.open_by_url(spreadsheet_url)

# Sheet 선택 (이름)
sheet = doc.worksheet("설문지 응답 시트1")

#메일 답변 여부 확인
sheet.update_acell('K1', "링크 발송 여부")
# Out:
# {'spreadsheetId': '1QjtdghWeypM-vGUkQADaDkJUEljV44IPViFeR43zvvM',
#  'updatedRange': "'설문지 응답 시트1'!K1",
#  'updatedRows': 1,
#  'updatedColumns': 1,
#  'updatedCells': 1}

# %%
# 모든 값을 dict로 가져오기
list_of_dicts = sheet.get_all_records()
print(len(list_of_dicts))
print(list_of_dicts)
# Out:
# 211
# [{'타임스탬프': '2022. 4. 29 오전 9:59:35', '이름': '고석호', '소속': '스크립스항체연구원', '직함/타이틀': '주임연구원', '이메일': 'logos@skai.or.kr', '전화번호': 1090579709, '참석하실 웨비나의 날짜를 선택하여 주세요 (5월 12일, 5월 26일, 6월 9일 마감).': '5월 12일', '지금 하고 계신 연구/업무 분야는 무엇인가요? (복수 선택 가능)': '면역학', 'NGS 기반 실험/분석/검사를 하고 계신가요?': '직접 실험부터 분석까지 하고 있다.', '위와 같이 개인정보를 수집·이용하는데 동의하십니까?': '예', '': 'Done'}, {'타임스탬프': '2022. 4. 29 오전 10:06:28', '이름': '김용찬', '소속': '전북대학교', '직함/타이틀': '박사후연구원', '이메일': 'rmeoskfo@hanmail.net', '전화번호': 1071185811, '참석하실 웨비나의 날짜를 선택하여 주세요 (5월 12일, 5월 26일, 6월 9일 마감).': '5월 26일', '지금 하고 계신 연구/업무 분야는 무엇인가요? (복수 선택 가능)': '희귀 질환, 바이오마커발굴, 생물정보학, 유전체학', 'NGS 기반 실험/분석/검사를 하고 계신가요?': '서비스기관에 의뢰해서 하고 있다.', '위와 같이 개인정보를 수집·이용하는데 동의하십니까?': '예', '': 'Done'}, {'타임스탬프': '2022. 4. 29 오전 10:16:42', '이름': '한진우', '소속': '연세대학교 의과대학 안과학교실', '직함/타이틀': '부교수', '이메일': 'jinuhan@yuhs.ac', '전화번호': '010-3764-7746', '참석하실 웨비나의 날짜를 선택하여 주세요 (5월 12일, 5월 26일, 6월 9일 마감).': '5월 26일', '지금 하고 계신 연구/업무 분
1025888044, '참석하실 웨비나의 날짜를 선택하여 주세요 (5월 12일, 5월 26일, 6월 9일 마감).': '5월 12일', '지금 하고 계신 연구/업무 분야는 무엇인가요? (복수 선택 가능)': '진단의학', 'NGS 기반 실험/분석/검사를 하고 계신가요?': '타 실험실/연구자에게 부탁하고 있다., 서비스기관에 의뢰해서 하고 있다.', '위와 같이 개인정보를 수집·이용하는데 동의하십니까?': '예', '': ''}, {'타임스탬프': '2022. 4. 29 오전 10:29:59', '이름': '설창안', '소속': 'GC지놈', '직함/타이틀': '전문의', '이메일': 'changahnseol@gmail.com', '전화번호': '031-260-9255', '참석하실 웨비나의 날짜를 선택하여 주세요 (5월 12일, 5월 26일, 6월 9일 마감).': '5월 12일', '지금 하고 계신 연구/업무 분야는 무엇인가요? (복수 선택 가능)': '희귀 질환, 생물정보학, 유전체학, 진단의학', 'NGS 기반 실험/분석/검사를 하고 계신가요?': '직접 실험부터 분석까지 하고 있다.', '위와 같이 개인정보를 수집·이용하는데 동의하십니까?': '예', '': ''}, {'타임스탬프': '2022. 4. 29 오전 10:36:45', '이름': '박은교', '소속': '강북삼성병원 코호트연구센터', '직함/타이틀': '연구원', '이메일': 'eunkyo85@gmail.com', '전화번호': 1091415424, '참석하실 웨비나의 날짜를 선택하여 주세요 (5월 12일, 5월 26일, 6월 9일 마감).': '5월 26일', '지금 하고 계신 연구/업무 분야는 무엇인가요? (복수 선택 가능)': '생물정보학, 유전체학', 'NGS 기반 실험/분석/검사를 하고 계신가요?': '직접 실험부터 분석까지 하고 있다.', '위와 같이 개인정보를 수집·이용하는데 동의하십니까?': '예', '': ''}, {'타임스탬프': '2022. 4. 29 오전 10:37:21', '이름': '우시재', '소속': '한국과학기술원', '직함/타이틀': '대학원생', '이메일': 'sijaewoo@kaist.ac.kr', '전화번호': '010-2972-3374', '참석하실 웨비나의 날짜를 선택하여 주세요 (5월 12일, 5월 26일, 6월 9일 마감).': '5월 12일', '지금 하고 계신 연구/업무 분야는 무엇인가요? (복수 선택 가능)': '희귀 질환', 'NGS 기반 실험/분석/검사를 하고 계신가요?': '직접 실험부터 분석까지 하고 있다.', '위와 같이 개인정보를 수집·이용하는데 동의하십니까?': '예', '': ''}, {'타임스탬프': '2022. 4. 29 오전 11:14: ...

# %%
tmp_num = 0

for x in list_of_dicts:
    print(x)
    tmp_num += 1
    if tmp_num == 5:
        break
# Out:
# {'타임스탬프': '2022. 4. 29 오전 9:59:35', '이름': '고석호', '소속': '스크립스항체연구원', '직함/타이틀': '주임연구원', '이메일': 'logos@skai.or.kr', '전화번호': 1090579709, '참석하실 웨비나의 날짜를 선택하여 주세요 (5월 12일, 5월 26일, 6월 9일 마감).': '5월 12일', '지금 하고 계신 연구/업무 분야는 무엇인가요? (복수 선택 가능)': '면역학', 'NGS 기반 실험/분석/검사를 하고 계신가요?': '직접 실험부터 분석까지 하고 있다.', '위와 같이 개인정보를 수집·이용하는데 동의하십니까?': '예', '': 'Done'}
# {'타임스탬프': '2022. 4. 29 오전 10:06:28', '이름': '김용찬', '소속': '전북대학교', '직함/타이틀': '박사후연구원', '이메일': 'rmeoskfo@hanmail.net', '전화번호': 1071185811, '참석하실 웨비나의 날짜를 선택하여 주세요 (5월 12일, 5월 26일, 6월 9일 마감).': '5월 26일', '지금 하고 계신 연구/업무 분야는 무엇인가요? (복수 선택 가능)': '희귀 질환, 바이오마커발굴, 생물정보학, 유전체학', 'NGS 기반 실험/분석/검사를 하고 계신가요?': '서비스기관에 의뢰해서 하고 있다.', '위와 같이 개인정보를 수집·이용하는데 동의하십니까?': '예', '': 'Done'}
# {'타임스탬프': '2022. 4. 29 오전 10:16:42', '이름': '한진우', '소속': '연세대학교 의과대학 안과학교실', '직함/타이틀': '부교수', '이메일': 'jinuhan@yuhs.ac', '전화번호': '010-3764-7746', '참석하실 웨비나의 날짜를 선택하여 주세요 (5월 12일, 5월 26일, 6월 9일 마감).': '5월 26일', '지금 하고 계신 연구/업무 분야는 무엇인가요? (복수 선택 가능)': '희귀 질환, 생물정보학, 유전체학', 'NGS 기반 실험/분석/검사를 하고 계신가요?': '직접 실험부터 분석까지 하고 있다.', '위와 같이 개인정보를 수집·이용하는데 동의하십니까?': '예', '': ''}
# {'타임스탬프': '2022. 4. 29 오전 10:19:04', '이름': '김정민', '소속': '국립보건연구원', '직함/타이틀': '책임공무직', '이메일': 'goodmin@gmail.com', '전화번호': '010-4025-0325', '참석하실 웨비나의 날짜를 선택하여 주세요 (5월 12일, 5월 26일, 6월 9일 마감).': '5월 12일', '지금 하고 계신 연구/업무 분야는 무엇인가요? (복수 선택 가능)': '희귀 질환, 유전체학', 'NGS 기반 실험/분석/검사를 하고 계신가요?': '아직 없다.', '위와 같이 개인정보를 수집·이용하는데 동의하십니까?': '예', '': ''}
# {'타임스탬프': '2022. 4. 29 오전 10:19:18', '이름': '김요나', '소속': '리뮤놀로지', '직함/타이틀': 'Cto', '이메일': 'yonafreesia@gmail.com', '전화번호': 1058154950, '참석하실 웨비나의 날짜를 선택하여 주세요 (5월 12일, 5월 26일, 6월 9일 마감).': '5월 12일', '지금 하고 계신 연구/업무 분야는 무엇인가요? (복수 선택 가능)': '종양학, 면역학, 신약개발', 'NGS 기반 실험/분석/검사를 하고 계신가요?': '서비스기관에 의뢰해서 하고 있다.', '위와 같이 개인정보를 수집·이용하는데 동의하십니까?': '예', '': ''}

# %%
sheet.update_acell('K3', "Done")
# Out:
# {'spreadsheetId': '1QjtdghWeypM-vGUkQADaDkJUEljV44IPViFeR43zvvM',
#  'updatedRange': "'설문지 응답 시트1'!K3",
#  'updatedRows': 1,
#  'updatedColumns': 1,
#  'updatedCells': 1}
